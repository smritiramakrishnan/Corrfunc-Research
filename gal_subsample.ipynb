# %%
import os.path as path
import numpy as np
import Corrfunc
from Corrfunc.theory.DDrppi import DDrppi
from numpy import random
import matplotlib.pyplot as plt
import import_ipynb
from functions import plot_results, error_data, wp_vs_rpavg, error_v_rp, simulate, plot_fractional_error

# %%
nbins = 20
rmin = 0.1
rmax = 20.0
rbins = np.logspace(np.log10(0.1), np.log10(rmax), nbins + 1)

# %% [markdown]
# # Mass > 10**14

# %% [markdown]
# ## Scale = 0

# %%
wp_sim_14_10_0, rp_sim_14_10_0, n_gal_14_10_0 = simulate(rbins, scale_ = 0, range_ = True, var = 'mass', min = 10**14, gal_sub = 0.1)

# %%
np.savez('subsamp_14_10_0', rp = rp_sim_14_10_0, wp = wp_sim_14_10_0, n_gal = n_gal_14_10_0)

# %%
data_14_10_0 = np.load('subsamp_14_10_0.npz')
wp_14_10_0 = data_14_10_0['wp']
rpavg_14_10_0 = data_14_10_0['rp']
plot_results(rpavg_14_10_0, wp_14_10_0, labels = data_14_10_0['n_gal'])

# %%
rp_14_10_0_mean, wp_14_10_0_mean, stdev_14_10_0 = error_data(rpavg_14_10_0, wp_14_10_0)
wp_vs_rpavg(rp_14_10_0_mean, wp_14_10_0_mean, stdev_14_10_0)
plt.show()
error_v_rp(rp_14_10_0_mean, stdev_14_10_0)
plt.show()
plot_fractional_error(stdev_14_10_0, wp_14_10_0_mean, rp_14_10_0_mean)

# %%
wp_sim_14_1_0, rp_sim_14_1_0, n_gal_14_1_0 = simulate(rbins, scale_ = 0, range_ = True, var = 'mass', min = 10**14, gal_sub = 0.01) 
np.savez('subsamp_14_1_0', rp = rp_sim_14_1_0, wp = wp_sim_14_1_0, n_gal = n_gal_14_1_0)

# %%
data_14_1_0 = np.load('subsamp_14_1_0.npz')
wp_14_1_0 = data_14_1_0['wp']
rpavg_14_1_0 = data_14_1_0['rp']
plot_results(rpavg_14_1_0, wp_14_1_0, labels = data_14_1_0['n_gal'])

# %%
rp_14_1_0_mean, wp_14_1_0_mean, stdev_14_1_0 = error_data(rpavg_14_1_0, wp_14_1_0)
wp_vs_rpavg(rp_14_1_0_mean, wp_14_1_0_mean, stdev_14_1_0)
plt.show()
error_v_rp(rp_14_1_0_mean, stdev_14_1_0)
plt.show()
plot_fractional_error(stdev_14_1_0, wp_14_1_0_mean, rp_14_1_0_mean)

# %%
wp_sim_14_001_0, rp_sim_14_001_0, n_gal_14_001_0 = simulate(rbins, scale_ = 0, range_ = True, var = 'mass', min = 10**14, gal_sub = 0.001) 
np.savez('subsamp_14_001_0', rp = rp_sim_14_001_0, wp = wp_sim_14_001_0, n_gal = n_gal_14_001_0)

# %%
data_14_001_0 = np.load('subsamp_14_001_0.npz')
wp_14_001_0 = data_14_001_0['wp']
rpavg_14_001_0 = data_14_001_0['rp']
plot_results(rpavg_14_001_0, wp_14_001_0, labels = data_14_001_0['n_gal'])

# %%
rp_14_001_0_mean, wp_14_001_0_mean, stdev_14_001_0 = error_data(rpavg_14_001_0, wp_14_001_0)
wp_vs_rpavg(rp_14_001_0_mean, wp_14_001_0_mean, stdev_14_001_0)
plt.show()
error_v_rp(rp_14_001_0_mean, stdev_14_001_0)
plt.show()
plot_fractional_error(stdev_14_001_0, wp_14_001_0_mean, rp_14_001_0_mean)

# %%
plot_fractional_error(stdev_14_10_0, wp_14_10_0_mean, rp_14_10_0_mean)
plot_fractional_error(stdev_14_1_0, wp_14_1_0_mean, rp_14_1_0_mean)
plot_fractional_error(stdev_14_001_0, wp_14_001_0_mean, rp_14_001_0_mean)
plt.legend(['10%', '1%', '0.1%'])
plt.show()

# %% [markdown]
# ## Scale = 30

# %%
wp_sim_14_10_30, rp_sim_14_10_30, n_gal_14_10_30 = simulate(rbins, scale_ = 30, range_ = True, var = 'mass', min = 10**14, gal_sub = 0.1) 
np.savez('subsamp_14_10_30', rp = rp_sim_14_10_30, wp = wp_sim_14_10_30, n_gal = n_gal_14_10_30)

# %%
data_14_10_30 = np.load('subsamp_14_10_30.npz')
wp_14_10_30 = data_14_10_30['wp']
rpavg_14_10_30 = data_14_10_30['rp']
plot_results(rpavg_14_10_30, wp_14_10_30, labels = data_14_10_30['n_gal'])

# %%
rp_14_10_30_mean, wp_14_10_30_mean, stdev_14_10_30 = error_data(rpavg_14_10_30, wp_14_10_30)
wp_vs_rpavg(rp_14_10_30_mean, wp_14_10_30_mean, stdev_14_10_30)
plt.show()
error_v_rp(rp_14_10_30_mean, stdev_14_10_30)
plt.show()
plot_fractional_error(stdev_14_10_30, wp_14_10_30_mean, rp_14_10_30_mean)

# %%
wp_sim_14_1_30, rp_sim_14_1_30, n_gal_14_1_30 = simulate(rbins, scale_ = 30, range_ = True, var = 'mass', min = 10**14, gal_sub = 0.01) 
np.savez('subsamp_14_1_30', rp = rp_sim_14_1_30, wp = wp_sim_14_1_30, n_gal = n_gal_14_1_30)

# %%
data_14_1_30 = np.load('subsamp_14_1_30.npz')
wp_14_1_30 = data_14_1_30['wp']
rpavg_14_1_30 = data_14_1_30['rp']
plot_results(rpavg_14_1_30, wp_14_1_30, labels = data_14_1_30['n_gal'])

# %%
rp_14_1_30_mean, wp_14_1_30_mean, stdev_14_1_30 = error_data(rpavg_14_1_30, wp_14_1_30)
wp_vs_rpavg(rp_14_1_30_mean, wp_14_1_30_mean, stdev_14_1_30)
plt.show()
error_v_rp(rp_14_1_30_mean, stdev_14_1_30)
plt.show()
plot_fractional_error(stdev_14_1_30, wp_14_1_30_mean, rp_14_1_30_mean)

# %%
wp_sim_14_001_30, rp_sim_14_001_30, n_gal_14_001_30 = simulate(rbins, scale_ = 30, range_ = True, var = 'mass', min = 10**14, gal_sub = 0.001) 
np.savez('subsamp_14_001_30', rp = rp_sim_14_001_30, wp = wp_sim_14_001_30, n_gal = n_gal_14_001_30)

# %%
data_14_001_30 = np.load('subsamp_14_001_30.npz')
wp_14_001_30 = data_14_001_30['wp']
rpavg_14_001_30 = data_14_001_30['rp']
plot_results(rpavg_14_001_30, wp_14_001_30, labels = data_14_001_30['n_gal'])

# %%
rp_14_001_30_mean, wp_14_001_30_mean, stdev_14_001_30 = error_data(rpavg_14_001_30, wp_14_001_30)
wp_vs_rpavg(rp_14_001_30_mean, wp_14_001_30_mean, stdev_14_001_30)
plt.show()
error_v_rp(rp_14_001_30_mean, stdev_14_001_30)
plt.show()
plot_fractional_error(stdev_14_001_30, wp_14_001_30_mean, rp_14_001_30_mean)

# %%
plot_fractional_error(stdev_14_10_30, wp_14_10_30_mean, rp_14_10_30_mean)
plot_fractional_error(stdev_14_1_30, wp_14_1_30_mean, rp_14_1_30_mean)
plot_fractional_error(stdev_14_001_30, wp_14_001_30_mean, rp_14_001_30_mean)
plt.legend(['10%', '1%', '0.1%'])

# %% [markdown]
# # Mass > 10**13

# %% [markdown]
# ## Scale = 0

# %%
wp_sim_13_10_0, rp_sim_13_10_0, n_gal_13_10_0 = simulate(rbins, scale_ = 0, range_ = True, var = 'mass', min = 10**13, gal_sub = 0.1) 
np.savez('subsamp_13_10_0', rp = rp_sim_13_10_0, wp = wp_sim_13_10_0, n_gal = n_gal_13_10_0)

# %%
data_13_10_0 = np.load('subsamp_13_10_0.npz')
wp_13_10_0 = data_13_10_0['wp']
rpavg_13_10_0 = data_13_10_0['rp']
plot_results(rpavg_13_10_0, wp_13_10_0, labels = data_13_10_0['n_gal'])

# %%
rp_13_10_0_mean, wp_13_10_0_mean, stdev_13_10_0 = error_data(rpavg_13_10_0, wp_13_10_0)
wp_vs_rpavg(rp_13_10_0_mean, wp_13_10_0_mean, stdev_13_10_0)
plt.show()
error_v_rp(rp_13_10_0_mean, stdev_13_10_0)
plt.show()
plot_fractional_error(stdev_13_10_0, wp_13_10_0_mean, rp_13_10_0_mean)

# %%
wp_sim_13_1_0, rp_sim_13_1_0, n_gal_13_1_0 = simulate(rbins, scale_ = 0, range_ = True, var = 'mass', min = 10**13, gal_sub = 0.01) 
np.savez('subsamp_13_1_0', rp = rp_sim_13_1_0, wp = wp_sim_13_1_0, n_gal = n_gal_13_1_0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 wp_sim_13_1_0, rp_sim_13_1_0, n_gal_13_1_0 = simulate(rbins, scale_ = 0, range_ = True, var = 'mass', min = 10**13, gal_sub = 0.01)
#       2 np.savez('subsamp_13_1_0', rp = rp_sim_13_1_0, wp = wp_sim_13_1_0, n_gal = n_gal_13_1_0)
#
# File <string>:150, in simulate(rbins, scale_, max_, range_, var, min, gal_sub)
#
# File <string>:11, in create_data(fname, range_, var, min)
#
# File ~/.conda/envs/mamba_env/lib/python3.9/site-packages/fitsio/fitslib.py:153, in read(filename, ext, extver, columns, rows, header, case_sensitive, upper, lower, vstorage, verbose, trim_strings, **keys)
#     149         raise IOError("No extensions have data")
#     151 item = _make_item(ext, extver=extver)
# --> 153 data = fits[item].read(**read_kwargs)
#     154 if header:
#     155     h = fits[item].read_header()
#
# ...

# %%
data_13_1_0 = np.load('subsamp_13_1_0.npz')
wp_13_1_0 = data_13_1_0['wp']
rpavg_13_1_0 = data_13_1_0['rp']
plot_results(rpavg_13_1_0, wp_13_1_0, labels = data_13_1_0['n_gal'])

# %%
rp_13_1_0_mean, wp_13_1_0_mean, stdev_13_1_0 = error_data(rpavg_13_1_0, wp_13_1_0)
wp_vs_rpavg(rp_13_1_0_mean, wp_13_1_0_mean, stdev_13_1_0)
plt.show()
error_v_rp(rp_13_1_0_mean, stdev_13_1_0)
plt.show()
plot_fractional_error(stdev_13_1_0, wp_13_1_0_mean, rp_13_1_0_mean)

# %%
wp_sim_13_001_0, rp_sim_13_001_0, n_gal_13_001_0 = simulate(rbins, scale_ = 0, range_ = True, var = 'mass', min = 10**13, gal_sub = 0.001) 
np.savez('subsamp_13_001_0', rp = rp_sim_13_001_0, wp = wp_sim_13_001_0, n_gal = n_gal_13_001_0)

# %%
data_13_001_0 = np.load('subsamp_13_001_0.npz')
wp_13_001_0 = data_13_001_0['wp']
rpavg_13_001_0 = data_13_001_0['rp']
plot_results(rpavg_13_001_0, wp_13_001_0, labels = data_13_001_0['n_gal'])

# %%
rp_13_001_0_mean, wp_13_001_0_mean, stdev_13_001_0 = error_data(rpavg_13_001_0, wp_13_001_0)
wp_vs_rpavg(rp_13_001_0_mean, wp_13_001_0_mean, stdev_13_001_0)
plt.show()
error_v_rp(rp_13_001_0_mean, stdev_13_001_0)
plt.show()
plot_fractional_error(stdev_13_001_0, wp_13_001_0_mean, rp_13_001_0_mean)

# %%
plot_fractional_error(stdev_13_10_0, wp_13_10_0_mean, rp_13_10_0_mean)
plot_fractional_error(stdev_13_1_0, wp_13_1_0_mean, rp_13_1_0_mean)
plot_fractional_error(stdev_13_001_0, wp_13_001_0_mean, rp_13_001_0_mean)
plt.legend(['10%', '1%', '0.1%'])
plt.show()

# %% [markdown]
# ## Scale = 30

# %%
wp_sim_13_10_30, rp_sim_13_10_30, n_gal_13_10_30 = simulate(rbins, scale_ = 30, range_ = True, var = 'mass', min = 10**13, gal_sub = 0.1) 
np.savez('subsamp_13_10_30', rp = rp_sim_13_10_30, wp = wp_sim_13_10_30, n_gal = n_gal_13_10_30)

# %%
data_13_10_30 = np.load('subsamp_13_10_30.npz')
wp_13_10_30 = data_13_10_30['wp']
rpavg_13_10_30 = data_13_10_30['rp']
plot_results(rpavg_13_10_30, wp_13_10_30, labels = data_13_10_30['n_gal'])

# %%
rp_13_10_30_mean, wp_13_10_30_mean, stdev_13_10_30 = error_data(rpavg_13_10_30, wp_13_10_30)
wp_vs_rpavg(rp_13_10_30_mean, wp_13_10_30_mean, stdev_13_10_30)
plt.show()
error_v_rp(rp_13_10_30_mean, stdev_13_10_30)
plt.show()
plot_fractional_error(stdev_13_10_30, wp_13_10_30_mean, rp_13_10_30_mean)

# %%
wp_sim_13_1_30, rp_sim_13_1_30, n_gal_13_1_30 = simulate(rbins, scale_ = 30, range_ = True, var = 'mass', min = 10**13, gal_sub = 0.01) 
np.savez('subsamp_13_1_30', rp = rp_sim_13_1_30, wp = wp_sim_13_1_30, n_gal = n_gal_13_1_30)

# %%
data_13_1_30 = np.load('subsamp_13_1_30.npz')
wp_13_1_30 = data_13_1_30['wp']
rpavg_13_1_30 = data_13_1_30['rp']
plot_results(rpavg_13_1_30, wp_13_1_30, labels = data_13_1_30['n_gal'])

# %%
rp_13_1_30_mean, wp_13_1_30_mean, stdev_13_1_30 = error_data(rpavg_13_1_30, wp_13_1_30)
wp_vs_rpavg(rp_13_1_30_mean, wp_13_1_30_mean, stdev_13_1_30)
plt.show()
error_v_rp(rp_13_1_30_mean, stdev_13_1_30)
plt.show()
plot_fractional_error(stdev_13_1_30, wp_13_1_30_mean, rp_13_1_30_mean)

# %%
wp_sim_13_001_30, rp_sim_13_001_30, n_gal_13_001_30 = simulate(rbins, scale_ = 30, range_ = True, var = 'mass', min = 10**13, gal_sub = 0.001) 
np.savez('subsamp_13_001_30', rp = rp_sim_13_001_30, wp = wp_sim_13_001_30, n_gal = n_gal_13_001_30)

# %%
data_13_001_30 = np.load('subsamp_13_001_30.npz')
wp_13_001_30 = data_13_001_30['wp']
rpavg_13_001_30 = data_13_001_30['rp']
plot_results(rpavg_13_001_30, wp_13_001_30, labels = data_13_001_30['n_gal'])

# %%
rp_13_001_30_mean, wp_13_001_30_mean, stdev_13_001_30 = error_data(rpavg_13_001_30, wp_13_001_30)
wp_vs_rpavg(rp_13_001_30_mean, wp_13_001_30_mean, stdev_13_001_30)
plt.show()
error_v_rp(rp_13_001_30_mean, stdev_13_001_30)
plt.show()
plot_fractional_error(stdev_13_001_30, wp_13_001_30_mean, rp_13_001_30_mean)

# %%
plot_fractional_error(stdev_13_10_30, wp_13_10_30_mean, rp_13_10_30_mean)
plot_fractional_error(stdev_13_1_30, wp_13_1_30_mean, rp_13_1_30_mean)
plot_fractional_error(stdev_13_001_30, wp_13_001_30_mean, rp_13_001_30_mean)
plt.legend(['10%', '1%', '0.1%'])
plt.show()
